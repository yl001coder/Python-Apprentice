# %% [markdown]
# # Strings
#
# We've already seen strings, so let's take some time to understand them better. Here is a really basic string
# assignment:
#
# ```python
# message = "Hello World!"
# ```
#
# You can create strings with different kinds of quotes. These are all basically the same, but each has a slightly different purpose:
#
# ```python
# message = "Hello World!"
# message = 'Hello World!'
# message = """Hello World!"""
# ```
#
# The reason for single and double quotes is so you can
# put the other kind of quote inside.
#
# ```python
# message = " You're allowed to put single quotes inside double quotes"
# message = ' He said "You can use double quotes inside single quotes." '
# ```
#
# You've seen the triple quote form at the top of your assignments,
# where it gives you the instructions about how to complete the lesson. The
# really important part of triple quotes is that it can span multiple lines,
# and you can also have single and double quotes inside.
#
# ```python
#
# message = """
# “Hope” is the thing with feathers -
# That perches in the soul -
# And sings the tune without the words -
# And never stops - at all -
# """
# ```
#
# ## Escaping
#
# There are some special characters that are hard to put into strings; they require a
# special prefix character, and adding that character is called "escaping" or "quoting".
#
# For instance, you can put a double quote inside of a double quote string, but
# you have put a slash in front of it.
#
# ```python
# message = ' You\'re allowed to put single quotes inside single quotes, if you escape it '
# message = " He said \"You can use double quotes inside single quotes, if you escape\" "
# ```
#
# Notice the `\'` and `\"` characters in the strings. There are a lot of other characters
# that you might escape, but there are only two that you will use most of the time:
#
# * `\n` ends a line and starts a new one.
# * `\t` is a tab. It moves the next character to the next tab stop (usually every 4 or 8 characters).
#
# Here is an example of using `\n` and `\t` in a string.

# %%
# Tabs and Newlines

s = "a\tb?\tc!!\t\n1\t2\t3\t\n"
print(s)
# Out:
# a	b?	c!!
# 1	2	3

# %% [markdown]
# Notice that the 1,2,3 line up with the a,b?,c!!, even though the strings are
# different lengths. Using the `\t` the first time makes the next character always
# start at column 8, and the second one makes it always start at column 16. You
# can use this for basic formatting.
#
#
# # Test Yourself
#
# Create two strings and print them out.
# The first string will have multiple line and have a 'Roses are Red' poem. Use triple quotes
#
# The second string will use double quotes and have a list of your friends first names and their ages,
# with their ages lined up in the second column.

# %%
# Test Yourself

poem = """
[Lucifer]
You're acting out like you want teacher's attention,
well, I'm the principal of this eternal detention,
I hope you've had your fun,
but son, it's time to ring the bell
(ding-dang)
Sinnerman, you're getting way too big for your screen
I'm here to drop your punishment,
it's gonna be mean,
just in case y'all had forgotten who's the motherF******
king of Hell (oh yeah!)
'Cause I'm the serpent, I'm the flame,
the mortal world is scared to say my name,
I am so spooky! 
I'm the s***!
I am a living aspect of the infinite!
So scheme all you want, Mr. TV-Head-Man,
I'm nearly a god, who are you?
Just a DEAD MAN
(music ends)

[Vox]
It's curious you stopped by,
to fight me nail and tooth,
when all I mean to try is to dispense a dose of truth
We sinners do not need a king!
We need someone who understands,
a different kind of despot bringing respot upon divine demands,
Just imagine if we could,
FLIP. THE. SCRIPT!
take the fight back way upstairs and,
make 'em beg and say their prayers and,
what would happen if we could, 
RUN. THIS. SHIP?
Hoist the mainsails, paint the decks,
(aye-aye)
Have a crewmate to protect 'cause,
they want us all divided, that is how they keep us down,
we got the guts!
We got the chutzpah!
We got the means to seize the crown,
If you're not f****** stupid,
then you've only got one choice,
Me! Vox Populi, the people's voice,
try to picture if we could,
escape this hole,
never have to live in fear of,
days that angels may appear 'cause,
here's the kicker! 
Sinners can, 
save, their, souls!
Not by changing for redemption,
but by taking over Heaven,
they say Hell's too populated,
that's why they exterminate!
We got the numbers!
We got the thunder!
Let's annex their real estate
If you wanna see a new world,
Raise your fists and make some noise!
(Hail Vox Populi, the people's voice)

Manifest destiny,
as long as you'll invest in me,
the rest'll all, fit into place!

[Vox, spoken]
Meanwhile, this KING,
thinks all of us PEASANTS,
should be happy wit h the endless existence of suffering!
Tell me Hell, are you satisfied? (No!)
Your wife knew it was wrong, Lu,
maybe that's why she's not around anymore!

[Lucifer, spoken]
You mouthy little mortal!

[Vox, spoken]
They didn't banish you,
They clipped your wings and chained you down here!
Well I got no chains on me!
Who's with me!

[Audience, VOX]
Let's unite and fight for a brand new realm! (BRAND NEW REALM)
We'll direct our destinies as,
one nation under the Vees and,
Happy days are nigh with Vox,
At! The! Helm! (THAT'S ME!)
Future's never tasted sweeter,
thanks to our charming leader!
Every sinner can be a winner,
so let's take our fates to the pearly gates
We can have the keys,
If we trust the Vees! 
Give applause, Hell has cause to rejoice!
Hail Vox Populi, the people's voice!
"""

print(poem)

friends = ""

print(friends)

# Hint: you will need \t and \n in the friends string, but not in the poem.
# Out:
# [Lucifer]
# You're acting out like you want teacher's attention,
# well, I'm the principal of this eternal detention,
# I hope you've had your fun,
# but son, it's time to ring the bell
# (ding-dang)
# Sinnerman, you're getting way too big for your screen
# I'm here to drop your punishment,
# it's gonna be mean,
# just in case y'all had forgotten who's the motherF******
# king of Hell (oh yeah!)
# 'Cause I'm the serpent, I'm the flame,
# the mortal world is scared to say my name,
# I am so spooky!
# I'm the s***!
# I am a living aspect of the infinite!
# So scheme all you want, Mr. TV-Head-Man,
# I'm nearly a god, who are you?
# Just a DEAD MAN
# (music ends)
#
# [Vox]
# It's curious you stopped by,
# to fight me nail and tooth,
# when all I mean to try is to dispense a dose of truth
# We sinners do not need a king!
# We need someone who understands,
# a different kind of despot bringing respot upon divine demands,
# Just imagine if we could,
# FLIP. THE. SCRIPT!
# take the fight back way upstairs and,
# make 'em beg and say their prayers and,
# what would happen if we could,
# RUN. THIS. SHIP?
# Hoist the mainsails, paint the decks,
# (aye-aye)
# Have a crewmate to protect 'cause,
# they want us all divided, that is how they keep us down,
# we got the guts!
# We got the chutzpah!
# We got the means to seize the crown,
# If you're not f****** stupid,
# then you've only got one choice,
# Me! Vox Populi, the people's voice,
# try to picture if we could,
# escape this hole,
# never have to live in fear of,
# days that angels may appear 'cause,
# here's the kicker!
# Sinners can,
# save, their, souls!
# Not by changing for redemption,
# but by taking over Heaven,
# they say Hell's too populated,
# that's why they exterminate!
# We got the numbers!
# We got the thunder!
# Let's annex their real estate
# If you wanna see a new world,
# Raise your fists and make some noise!
# (Hail Vox Populi, the people's voice)
#
# Manifest destiny,
# as long as you'll invest in me,
# the rest'll all, fit into place!
#
# [Vox, spoken]
# Meanwhile, this KING,
# thinks all of us PEASANTS,
# should be happy wit h the endless existence of suffering!
# Tell me Hell, are you satisfied? (No!)
# Your wife knew it was wrong, Lu,
# maybe that's why she's not around anymore!
#
# [Lucifer, spoken]
# You mouthy little mortal!
#
# [Vox, spoken]
# They didn't banish you,
# They clipped your wings and chained you down here!
# Well I got no chains on me!
# Who's with me!
#
# [Audience, VOX]
# Let's unite and fight for a brand new realm! (BRAND NEW REALM)
# We'll direct our destinies as,
# one nation under the Vees and,
# Happy days are nigh with Vox,
# At! The! Helm! (THAT'S ME!)
# Future's never tasted sweeter,
# thanks to our charming leader!
# Every sinner can be a winner,
# so let's take our fates to the pearly gates
# We can have the keys,
# If we trust the Vees!
# Give applause, Hell has cause to rejoice!
# Hail Vox Populi, the people's voice!

# %% [markdown]
# # Fancy Formatting
#
# Python has several different ways to format a string; we are going to practice
# the newest, and most important one. These are called 'f strings' and here is what
# they look like:

# %%
# f-strings

age = 14
name = "John"

print(f"{name} is {age} years old.")
# Out:
# John is 14 years old.

# %% [markdown]
# The important parts of the `f` string is
#
# * It starts with 'f'
# * You can insert variables inside it by surrounding them with curly braces, `{}`
#
# Here are some more important things you can do with f-strings.

# %%
# More F-Strings

# You can put lots of expressions inside the curly braces, not just variable names

print(f"{name.lower()} is {age} years old. In 5 years, he will be {age + 5} years old.")

# You can add a colon after the variable name to format the output
# For instance, to make a number appear with commas as thousands separators, you can write {number:,}
# or to make it have only 2 decimal places, you can write {number:.2f}

number = 1234567.890123

print(f"With a separator: {number:,}")
print(f"Rounded to 2 places: {number:.2f}")

# You can make a string appear in a certain number of spaces by writing {string:10}
# This will make the string appear in a space of 10 characters, padding it with spaces if necessary

print(f"{'Hello':10}{'World':10}!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # More F-Strings
#       2
#       3 # You can put lots of expressions inside the curly braces, not just variable names
# ----> 5 print(f"{name.lower()} is {age} years old. In 5 years, he will be {age + 5} years old.")
#       7 # You can add a colon after the variable name to format the output
#       8 # For instance, to make a number appear with commas as thousands separators, you can write {number:,}
#       9 # or to make it have only 2 decimal places, you can write {number:.2f}
#      11 number = 1234567.890123
#
# NameError: name 'name' is not defined

# %% [markdown]
# You can combine f-strings and triple quotes for a very powerful method of formatting.

# %%
# Run Me

name = "John"
age = 14
prize = "an abusive ex"

letter = f"""
Dear {name},

Congratulations! You have won {prize} in our prize draw. 
You are only {age} years old, so you must be very lucky!

Yours sincerely,
The Prize Draw Team
"""

print(letter)
# Out:
# Dear John,
#
# Congratulations! You have won a unicorn in our prize draw.
# You are only 14 years old, so you must be very lucky!
#
# Yours sincerely,
# The Prize Draw Team

# %% [markdown]
# There is a lot more you can do with f-strings, but this will get you started.
#
# ## Test Yourself
#
# In the loop, print out:
#
# * start each line with "!"
# * The line number, formatted to 3 spaces
# * The string "equations" followed by a math equation showing the number times 2
# * the last number is formatted to 5 spaces
#
# For instance, one of the lines should look like
#
# ```python
# !  6 equation: 6 * 2 =    12
# ```

# %%
# Test Yourself

for i in range(1, 9):
    ...

# %% [markdown]
# # Turning Strings to List
#
# Let's review how to strings into lists. There are two important ways.
#
# First, you can turn it directly into a list with `list()`

# %%
print(list("Hello World"))

# %% [markdown]
# Second, you can break it up on a character with `split()`:

# %%
# Split on spaces
m = "Python is fun to learn"
l = m.split()
print(l)

# %% [markdown]
# The `.split()` method splits on spaces by default, but you can specify a
# different character to split on by passing it as an argument to the method.

# %%
# split on commas

m = 'a,b,c,d,e'
l = m.split(',')
print(l)

# %% [markdown]
# After you have split a string, you can rejoin it. There is a funny way to do it,
# which we will have to explain later; for now just use this method.

# %%
# Run Me!
# Join with spaces
l = ['Python', 'is', 'fun', 'to', 'learn']
s = ' '.join(l) # Doesn't that look weird?
print(s)

# Join with commas
l = ['a', 'b', 'c', 'd', 'e']
s = ','.join(l)
print(s)

# %% [markdown]
# So, if you wanted to change the third word of a sentence, you might do:

# %%
# Run Me!
m = "Python is fun to learn"
l = m.split() # Turn it into a list of words
l[2] = 'amazing' # Change the third word
s = ' '.join(l) # Join the words back together

print(s)
# Out:
# Python is amazing to learn

# %% [markdown]
# If you wanted to add a word in the middle you might do:

# %%
# Run Me!
m = "Python is fun to learn"
l = m.split() # Turn it into a list of words

first_half = l[:2] # Get the first two words
second_half = l[2:] # Get the rest of the words

l = first_half + ['really'] + second_half # Add 'really' in the middle, using + to combine lists

s = ' '.join(l) # Join the words back together

s

# %% [markdown]
# # Test Yourself
#
# Use the strings and lists, along with `+`, `.split()`, slicing and indexing, to assemble and print out phrases.
#
# Hints:
#
# * You might need to use the string methods `.lower()` or `.capitalize()`
# * You can extract words using either a slice on a string, or convert the string to a list first.
#
# First, here is an example:

# %%
# Example

s1 = "Pythons are constrictors!"
s2 = "John is funny"

# Print "Python is fun" 

space = s1[7]
s = s1[:6] + space + s2[5:-2] + s1[-1]
print(s)

# or
dot = "."
words1 = s1.split()
pythons = words1[0]
python = pythons[:-1]
words2 = s2.split()
is_word = words2[1] # 'is' is a reserved word in Python, so we can't use it as a variable name
funny = words2[2]
fun = funny[:-2]
exclaim = s1[-1]

print(s)
print(python  + space + is_word + space + fun + exclaim)
# Out:
# Python is fun!
# Python is fun!
# Python is fun!

# %% [markdown]
# Now you try it:

# %%
# Test yourself 

s1 = "The train in Spain."
s2 = "makes passengers complain"
s3 = ["flowers", "grow", "again" ]
s4 = "to"
ace = " " 

l = s1.split()
m = s2.split()
n = s4.split()

l[3] = "Spain"
spain = l[3]
the = l[0]
train = l[1]
inwerd = l[2]

complain = m[2]
makes = m[0]
passw = m[1]

to = n[0]
dot = "."

flowers = s3[0]
grow = s3[1]
again = s3[2]
l[1] = "rain"
rain = l[1]
# Print "The train in Spain makes passengers complain."
print(the+ace+train+ace+inwerd+ace+spain+ace+makes+ace+passw+ace+complain+dot)
# Print "The rain in Spain makes flowers grow again"
print(the+ace+rain+ace+inwerd+ace+spain+ace+makes+ace+flowers+ace+grow+ace+again+dot)
# Print "The passengers grow flowers in Spain
print(the+ace+passw+ace+grow+ace+flowers+ace+inwerd+ace+spain)
# Print "The flowers in Spain train passengers to complain."
rain = "train"
print(the+ace+flowers+ace+inwerd+ace+spain+ace+rain+ace+passw+ace+to+ace+complain+dot)
# Out:
# The train in Spain makes passengers complain.
# The rain in Spain makes flowers grow again.
# The passengers grow flowers in Spain
# The flowers in Spain train passengers to complain.
